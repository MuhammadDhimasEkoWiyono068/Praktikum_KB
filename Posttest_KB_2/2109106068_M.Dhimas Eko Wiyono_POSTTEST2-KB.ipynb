# %% [markdown]
# # Import Library

# %%
import pandas as pd

# %% [markdown]
# # Membaca data dari file CSV ke dalam DataFrame

# %%
df = pd.read_csv("games-data.csv")

# %% [markdown]
# # Menampilkan rata-rata, standar deviasi, nilai minimum, nilai maksimum, Q1, Q2, dan Q3 dari attribute bertipe angka.

# %%
# Memilih semua kolom dengan tipe data numerik/angka
atribut_angka = df.select_dtypes(include=['number'])

# Menghitung statistik deskriptif menggunakan describe()
stats = atribut_angka.describe()

print("Rata-rata:")
print(stats.loc['mean'])

print("\n")

print("Standar Deviasi:")
print(stats.loc['std'])

print("\n")

print("Nilai Minimum:")
print(stats.loc['min'])

print("\n")

print("Nilai Maksimum:")
print(stats.loc['max'])

print("\n")

print("Q1:")
print(atribut_angka.quantile(0.25))

print("\n")

print("Q2(Median):")
print(atribut_angka.quantile(0.50))

print("\n")

print("Q3:")
print(atribut_angka.quantile(0.75))
# Out:
# Rata-rata:
# score       70.386647
# critics     23.149799
# users      172.797983
# Name: mean, dtype: float64
#
#
# Standar Deviasi:
# score        12.410885
# critics      17.152985
# users      1280.291974
# Name: std, dtype: float64
#
#
# Nilai Minimum:
# score      11.0
# critics     0.0
# users       0.0
# Name: min, dtype: float64
#
#
# Nilai Maksimum:
# score          99.0
# critics       126.0
# users      146262.0
# Name: max, dtype: float64
#
#
# Q1:
# score      63.0
# critics    11.0
# users      11.0
# Name: 0.25, dtype: float64
#
#
# Q2(Median):
# score      72.0
# critics    17.0
# users      28.0
# Name: 0.5, dtype: float64
#
#
# Q3:
# score      79.0
# critics    30.0
# users      90.0
# Name: 0.75, dtype: float64

# %% [markdown]
# # Menampilkan 10 record pertama dari dataset dengan attribute bertipe angka.

# %%
print(atribut_angka.head(10))
# Out:
#    score  critics  users
# 0     99       22   5749
# 1     98       19    647
# 2     98       64   3806
# 3     98       24    324
# 4     98       86   3364
# 5     97       73   3059
# 6     97       87   2521
# 7     97       33   3186
# 8     97       14   1285
# 9     97       50   4568

# %% [markdown]
# # Menampilkan informasi jumlah record, jumlah attribute, nama attribute, jumlah attribute dengan tipe angka. Masukkan informasi tersebut dalam dictionary dengan key sesuai nama informasinya.

# %%
# Menghitung jumlah baris (record) dalam dataset
jumlah_record = len(df)

# Menghitung jumlah atribut (kolom) dalam dataset
jumlah_attribute = len(df.columns)

# Mengambil daftar nama atribut (kolom) dalam dataset
nama_attribute = df.columns.tolist()

# Menghitung jumlah atribut yang memiliki tipe data numerik/angka
jumlah_attribute_angka = len(df.select_dtypes(include='number').columns)

# Membuat dictionary 'informasi_dataset'
informasi_dataset = {
    "Jumlah Record          ": jumlah_record,
    "Jumlah Attribute       ": jumlah_attribute,
    "Nama Attribute         ":  nama_attribute,
    "Jumlah Attribute Angka ": jumlah_attribute_angka
}

# Mencetak informasi dataset
for key, value in informasi_dataset.items():
    print(f"{key}: {value}")
# Out:
# Jumlah Record          : 17944
# Jumlah Attribute       : 10
# Nama Attribute         : ['name', 'platform', 'r-date', 'score', 'user score', 'developer', 'genre', 'players', 'critics', 'users']
# Jumlah Attribute Angka : 3

# %% [markdown]
# # Menampilkan nilai dataset pada baris dimulai dengan 3 digit NIM akhir(068) hingga data terakhir dan kolom ke 4 hingga kolom terakhir menggunakan ke 2 metode slice.
#
# -Metode iloc

# %%
df.iloc[68:, 3:]
# Out:
#        score user score               developer  \
# 68        94        6.6            InfinityWard
# 69        94        9.2          SCESantaMonica
# 70        94        8.4  NeversoftEntertainment
# 71        94        8.6                  Capcom
# 72        94        8.4            InfinityWard
# ...      ...        ...                     ...
# 17939     17        3.1                 Poisoft
# 17940     17        1.9                  Team17
# 17941     17        4.3   BackboneEntertainment
# 17942     16        1.3    Eutechnyx,DeepSilver
# 17943     11        2.0             ArtCo.,Ltd.
#
#                                                    genre  \
# 68     Action,Shooter,Shooter,First-Person,Modern,Mod...
# 69                               Action Adventure,Linear
# 70                      Sports,Alternative,Skateboarding
# 71                              Action Adventure,Fantasy
# 72     Action,Shooter,Shooter,First-Person,Modern,Mod...
# ...

# %% [markdown]
# -Metode loc

# %%
df.loc[68:, df.columns[3:]]
# Out:
#        score user score               developer  \
# 68        94        6.6            InfinityWard
# 69        94        9.2          SCESantaMonica
# 70        94        8.4  NeversoftEntertainment
# 71        94        8.6                  Capcom
# 72        94        8.4            InfinityWard
# ...      ...        ...                     ...
# 17939     17        3.1                 Poisoft
# 17940     17        1.9                  Team17
# 17941     17        4.3   BackboneEntertainment
# 17942     16        1.3    Eutechnyx,DeepSilver
# 17943     11        2.0             ArtCo.,Ltd.
#
#                                                    genre  \
# 68     Action,Shooter,Shooter,First-Person,Modern,Mod...
# 69                               Action Adventure,Linear
# 70                      Sports,Alternative,Skateboarding
# 71                              Action Adventure,Fantasy
# 72     Action,Shooter,Shooter,First-Person,Modern,Mod...
# ...

# %% [markdown]
# # Menampilkan jumlah nilai dari semua attribute yang bernilai object

# %%
# Mengidentifikasi kolom dengan tipe data objek (string)
kolom_objek = df.select_dtypes(include=['object'])

# Menginisialisasi dictionary untuk menyimpan hasil perhitungan
count_results = {}

# Menggunakan loop untuk menghitung jumlah nilai dalam setiap kolom objek
for kolom in kolom_objek:
    count_results[kolom] = df[kolom].value_counts()

# Menampilkan hasil perhitungan
for kolom, hasil in count_results.items():
    print("=======================================")
    print(f"Jumlah nilai dalam {kolom}:")
    print("=======================================")
    print(hasil, "\n")
# Out:
# ...
# Jumlah nilai dalam name:
# ...
# Madden NFL 07                                   9
# Cars                                            9
# Tiger Woods PGA Tour 08                         8
# Madden NFL 06                                   8
# Resident Evil: Revelations                      7
#                                                ..
# The Sims 3: Ambitions                           1
# Everybody's Golf VR                             1
# The Sims 3: Late Night Expansion Pack           1
# Inazuma Eleven Go: Light                        1
# Family Party: 30 Great Games Obstacle Arcade    1
# Name: name, Length: 11762, dtype: int64
#
# ...
# Jumlah nilai dalam platform:
# ...
# PC                 4592
# PlayStation4       1928
# Xbox360            1666
# PlayStation2       1418
# PlayStation3       1269
# Switch             1122
# XboxOne            1118
# Xbox                793
# DS                  730
# Wii                 664
# PSP                 513
# GameCube            452
# ...
